# %% [markdown]
# <a href="https://colab.research.google.com/github/iharshidas/LetsUpgradePython/blob/master/Pubg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Uploading file from Desktop into Google Colaboratory
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-71a70a5e-eb13-433b-a788-993ebb3024ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71a70a5e-eb13-433b-a788-993ebb3024ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pubg.csv to pubg.csv

# %% [markdown]
# **1.   Read the dataset.**

# %%
# Importing pandas and io to read the uploaded file
import pandas as pd 
import io 

df = pd.read_csv(io.BytesIO(uploaded['pubg.csv'])) 
print(df)
# Out:
#                   Id         groupId  ... winPoints  winPlacePerc
# 0     2f262dd9795e60  78437bcd91d40e  ...      1470        0.0000
# 1     a32847cf5bf34b  85b7ce5a12e10b  ...      1531        0.2222
# 2     1b1900a9990396  edf80d6523380a  ...         0        0.8571
# 3     f589dd03b60bf2  804ab5e5585558  ...         0        0.3462
# 4     c23c4cc5b78b35  b3e2cd169ed920  ...      1557        0.0690
# ...              ...             ...  ...       ...           ...
# 9995  ef4f474acd8e85  2eca2a8391f75d  ...      1471        0.8333
# 9996  cf0bf82fb4d80e  2eaf2765f93adb  ...      1500        0.7174
# 9997  a0a31a0b1dcbe1  8d50c64ccc5071  ...      1434        0.2083
# 9998  f6874657399d69  d31843d7e62ccb  ...      1534        0.2449
# 9999  90359b0b8f8b0d  61d5b1bb8da43f  ...         0        0.1875
#
# [10000 rows x 29 columns]

# %% [markdown]
# **2. Check the datatype of all the columns.**

# %%
# To get the data type of each column
print(df.dtypes)
# Out:
# Id                  object
# groupId             object
# matchId             object
# assists              int64
# boosts               int64
# damageDealt        float64
# DBNOs                int64
# headshotKills        int64
# heals                int64
# killPlace            int64
# killPoints           int64
# kills                int64
# killStreaks          int64
# longestKill        float64
# matchDuration        int64
# matchType           object
# maxPlace             int64
# numGroups            int64
# rankPoints           int64
# revives              int64
# rideDistance       float64
# roadKills            int64
# swimDistance       float64
# teamKills            int64
# vehicleDestroys      int64
# walkDistance       float64
# weaponsAcquired      int64
# winPoints            int64
# winPlacePerc       float64
# dtype: object

# %% [markdown]
# **3. Find the summary of all the numerical columns and write your findings about it.**

# %%
df.describe()
# Out:
#             assists        boosts  ...   winPoints  winPlacePerc
# count  10000.000000  10000.000000  ...  10000.0000  10000.000000
# mean       0.234600      1.088500  ...    609.3440      0.469926
# std        0.575149      1.703279  ...    739.7924      0.304508
# min        0.000000      0.000000  ...      0.0000      0.000000
# 25%        0.000000      0.000000  ...      0.0000      0.200000
# 50%        0.000000      0.000000  ...      0.0000      0.458300
# 75%        0.000000      2.000000  ...   1495.0000      0.735100
# max        7.000000     18.000000  ...   1863.0000      1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# **4. The average person kills how many players?**

# %%
df['kills'].mean()
# Out:
# 0.9134

# %% [markdown]
# **5. 99% of people have how many kills?**

# %%
df['kills'].quantile(0.99)
# Out:
# 7.0

# %% [markdown]
# **6. The most kills ever recorded are how much?**

# %%
df['kills'].max()
# Out:
# 35

# %% [markdown]
# **7. Print all the columns of the dataframe.**

# %%
df.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %% [markdown]
# **8. Comment on distribution of the match's duration. Use seaborn.**

# %%
# Import seaborn
import seaborn as sns
sns.distplot(df['matchDuration'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The highest time for which the most of the matches were being played was around 1375 minutes i.e., around 23 minutes.

# %% [markdown]
# **9. Comment on distribution of the walk distance. Use seaborn.**

# %%
sns.distplot(df['walkDistance'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# From the above plot, we can deduce that most of the distance was covered between 0-200 by foot.

# %% [markdown]
# **10. Plot distribution of the match's duration vs walk distance one below the other.**

# %%
# Importing matplotlib to plot subplots and other visualizations
import matplotlib.pyplot as plt

plt.subplot(2,1,1)
plt.plot(df['matchDuration'])
plt.xlabel('Match Duration')

plt.subplot(2,1,2)
plt.plot(df['walkDistance'])
plt.xlabel('Walk Distance')
# Out:
# Text(0.5, 0, 'Walk Distance')

# %% [markdown]
# **11. Plot distribution of the match's duration vs walk distance side by side.**

# %%
plt.subplot(1,2,1)
plt.plot(df['matchDuration'])
plt.xlabel('Match Duration')

plt.subplot(1,2,2)
plt.plot(df['walkDistance'])
plt.xlabel('Walk Distance')
# Out:
# Text(0.5, 0, 'Walk Distance')

# %% [markdown]
# **12. Pairplot the dataframe. Comment on kills vs damage dealt, Comment on maxPlace vs numGroups.**

# %%
sns.pairplot(df.head(100));

# %% [markdown]
# **13. How many unique values are there in 'matchType' and what are their counts?**

# %%
print(df['matchType'].unique())
len(df['matchType'].unique())
# Out:
# ['squad-fpp' 'squad' 'duo-fpp' 'solo-fpp' 'duo' 'solo' 'crashfpp'
#  'flaretpp' 'normal-squad-fpp' 'normal-duo-fpp' 'flarefpp' 'normal-squad'
#  'normal-solo-fpp' 'crashtpp']
# 14

# %% [markdown]
# **14. Plot a barplot of ‘matchType’ vs 'killPoints'. Write your inferences.**

# %%
plt.bar(df['matchType'],df['killPoints'])
plt.xlabel("Match Type")
plt.ylabel("Kill Points")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **15. Plot a barplot of ‘matchType’ vs ‘weaponsAcquired’. Write your inferences.**

# %%
plt.bar(df['matchType'],df['weaponsAcquired'])
plt.xlabel("Match Type")
plt.ylabel("Weapons Acquired")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **16. Find the Categorical columns.**

# %%
df.select_dtypes('category').columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# **17. Plot a boxplot of ‘matchType’ vs ‘winPlacePerc’. Write your inferences.**

# %%
g=sns.boxplot(x=df['matchType'],y=df['winPlacePerc'])
g.set_xticklabels(['squad-fpp', 'squad' ,'duo-fpp', 'solo-fpp', 'duo', 'solo', 'crashfpp',
 'flaretpp' ,'normal-squad-fpp', 'normal-duo-fpp' ,'flarefpp', 'normal-squad',
 'normal-solo-fpp', 'crashtpp'],rotation=90)
# Out:
# [Text(0, 0, 'squad-fpp'),
#  Text(0, 0, 'squad'),
#  Text(0, 0, 'duo-fpp'),
#  Text(0, 0, 'solo-fpp'),
#  Text(0, 0, 'duo'),
#  Text(0, 0, 'solo'),
#  Text(0, 0, 'crashfpp'),
#  Text(0, 0, 'flaretpp'),
#  Text(0, 0, 'normal-squad-fpp'),
#  Text(0, 0, 'normal-duo-fpp'),
#  Text(0, 0, 'flarefpp'),
#  Text(0, 0, 'normal-squad'),
#  Text(0, 0, 'normal-solo-fpp'),
#  Text(0, 0, 'crashtpp')]

# %% [markdown]
# **18. Plot a boxplot of ‘matchType’ vs ‘matchDuration’. Write your inferences.**

# %%
g=sns.boxplot(x=df['matchType'],y=df['matchDuration'])
g.set_xticklabels(['squad-fpp', 'squad' ,'duo-fpp', 'solo-fpp', 'duo', 'solo', 'crashfpp',
 'flaretpp' ,'normal-squad-fpp', 'normal-duo-fpp' ,'flarefpp', 'normal-squad',
 'normal-solo-fpp', 'crashtpp'],rotation=90)
# Out:
# [Text(0, 0, 'squad-fpp'),
#  Text(0, 0, 'squad'),
#  Text(0, 0, 'duo-fpp'),
#  Text(0, 0, 'solo-fpp'),
#  Text(0, 0, 'duo'),
#  Text(0, 0, 'solo'),
#  Text(0, 0, 'crashfpp'),
#  Text(0, 0, 'flaretpp'),
#  Text(0, 0, 'normal-squad-fpp'),
#  Text(0, 0, 'normal-duo-fpp'),
#  Text(0, 0, 'flarefpp'),
#  Text(0, 0, 'normal-squad'),
#  Text(0, 0, 'normal-solo-fpp'),
#  Text(0, 0, 'crashtpp')]

# %% [markdown]
# **19. Change the orientation of the above plot to horizontal.**

# %%
sns.boxplot(x=df['winPlacePerc'],y=df['matchType'])

# %% [markdown]
# **20. Add a new column called ‘KILL’ which contains the sum of following columns viz. headshotKills, teamKills, roadKills.**

# %%
df['KILL']=df['headshotKills']+df['teamKills']+df['roadKills']
df['KILL']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: KILL, Length: 10000, dtype: int64

# %% [markdown]
# **21. Round off column ‘winPlacePerc’ to 2 decimals.**

# %%
df['winPlacePerc']=round(df['winPlacePerc'],2)
df['winPlacePerc']
# Out:
# 0       0.00
# 1       0.22
# 2       0.86
# 3       0.35
# 4       0.07
#         ...
# 9995    0.83
# 9996    0.72
# 9997    0.21
# 9998    0.24
# 9999    0.19
# Name: winPlacePerc, Length: 10000, dtype: float64

# %% [markdown]
# **22. Take a sample of size 50 from the column damageDealt for 100 times and calculate its mean. Plot it on a histogram and comment on its distribution. **

# %%
mean=[]
for i in range(100):
  for x in range(0,1001,50):
    mean1=df['damageDealt'].head(x).mean()
    mean.append(mean1)
 
sns.histplot(data=df['damageDealt'], x=mean)
